# %% [markdown]
# In this notebook, I will look to demo fetching data from fbref using the python package BeautifulSoup (via fbref class). The aim is to be able to fetch data to be able to do analysis on how various teams on how they're doing in Europe's top five leagues. To do this we will use the FBref class to grab data for the following:
# * current league table
# * fixtures and results for given season
# * Match stats scuh as xG, shots, goals
# * Player stats for Europe's top five leagues
#
# Data grabbed from this class will clean data in the format ready for analysis.
#
# # Imports

# %%
import os
os.chdir("../")
# %autosave 0
# Out:
# Autosave disabled

# %%
from src.fbref.fbref_class import FBref

# %% [markdown]
# # Grabbing data using BeautifulSoup
#
# Example website we will look to scrape: https://fbref.com/en/
#
# ### Instantiate Fbref() class

# %%
fb = FBref()

# %% [markdown]
# ### Define beautifulsoup object for html page of interest
#
# The goal is to grab the table named Big 5 European Leagues as well as grabbing any hyperlinks. We will start by grabbing the html of the entire page

# %%
input_url = 'https://fbref.com/en/comps/9/2021-2022/2021-2022-Premier-League-Stats'

beautifulsoup_object = fb.instantiate_beautiful_soup_object(
    input_url
)

# %% [markdown]
# ### Grab competition dictionary

# %%
competition_dict = fb.get_competition_dict()

# %%
competition_dict
# Out:
# {'9': 'Premier-League',
#  '12': 'La-Liga',
#  '11': 'Serie-A',
#  '13': 'Ligue-1',
#  '20': 'Bundesliga'}

# %% [markdown]
# ### Get big five league table

# %%
big5_df = fb.get_big_5_leagues()

# %%
big5_df
# Out:
#                   Competition Name Gender  Country First Season Last Season  \
# 0                   Premier League      M  eng ENG    1888-1889   2022-2023
# 1                          La Liga      M   es ESP    1988-1989   2022-2023
# 2                          Ligue 1      M   fr FRA    1995-1996   2022-2023
# 3               Fußball-Bundesliga      M   de GER    1988-1989   2022-2023
# 4                          Serie A      M   it ITA    1988-1989   2022-2023
# 5  Big 5 European Leagues Combined      M             1995-1996   2022-2023
#
#   Tier                                   competition_link competition_id
# 0  1st  https://fbref.com/en/comps/9/history/Premier-L...              9
# 1  1st  https://fbref.com/en/comps/12/history/La-Liga-...             12
# 2  1st  https://fbref.com/en/comps/13/history/Ligue-1-...             13
# 3  1st  https://fbref.com/en/comps/20/history/Bundesli...             20
# 4  1st  https://fbref.com/en/comps/11/history/Serie-A-...             11
# 5  1st  https://fbref.com/en/comps/Big5/history/Big-5-...           Big5

# %% [markdown]
# ### Get league table
#
# Define parameters for competition_id and season_name

# %%
competition_id = '9'
season_name = '2022-2023'

# %% [markdown]
# Get league table for example season, Premier League 2022-2023

# %%
league_table_df = fb.get_season_stats_table('league_table', competition_id, season_name)
league_table_df.head(3)
# Out:
#    position             team  matches_played  wins  draws  losses  goals_for  \
# 0         1          Arsenal              28    22      3       3         66
# 1         2  Manchester City              27    19      4       4         67
# 2         3   Manchester Utd              26    15      5       6         41
#
#    goals_against  goal_difference  points  ...    xg  xg_against  \
# 0             26               40      69  ...  53.8        27.0
# 1             25               42      61  ...  56.1        21.5
# 2             35                6      50  ...  40.8        32.6
#
#    expected_goal_difference  expected_goal_difference_per_90  goals_per_game  \
# 0                      26.7                             0.95            2.36
# 1                      34.6                             1.28            2.48
# 2                       8.2                             0.31            1.58
#
#    goals_conceded_per_game  xg_per_game  xg_against_per_game  competition_id  \
# 0                     0.93         1.92                 0.96               9
# 1                     0.93         2.08                 0.80               9
# 2                     1.35         1.57                 1.25               9
#
#   season_name
# 0   2022_2023
# 1   2022_2023
# 2   2022_2023
#
# [3 rows x 21 columns]

# %% [markdown]
# ### Get Home and away league table

# %%
league_table_home_away_df = fb.get_season_stats_table('home_away_league_table', competition_id, season_name)
league_table_home_away_df.head(3)
# Out:
#    rk             squad  home_mp  home_w  home_d  home_l  home_gf  home_ga  \
# 0   1           Arsenal       14      11       2       1       38       17
# 1   2   Manchester City       13      11       1       1       43       13
# 2   3    Manchester Utd       13       9       3       1       24        8
#
#    home_gd  home_pts  ...  away_ga  away_gd  away_pts  away_pts_per_mp  \
# 0       21        35  ...        9       19        34             2.43
# 1       30        34  ...       12       12        27             1.93
# 2       16        30  ...       27      -10        20             1.54
#
#    away_xg  away_xga  away_xgd  away_xgd_per_90  competition_id  season_name
# 0     22.7      12.8       9.9             0.71               9    2022_2023
# 1     26.4      13.7      12.7             0.91               9    2022_2023
# 2     16.9      19.5      -2.7            -0.21               9    2022_2023
#
# [3 rows x 30 columns]

# %% [markdown]
# ### Get fixtures and results for example league and season

# %%
fixtures_df = fb.get_fixtures_and_results(competition_id, season_name)

# %%
fixtures_df.head(5)
# Out:
#    wk  day       date    time            home  home_xg score  away_xg  \
# 0   1  Fri 2022-08-05  20:00   Crystal Palace      1.2   0–2      1.0
# 1   1  Sat 2022-08-06  12:30           Fulham      1.2   2–2      1.2
# 2   1  Sat 2022-08-06  15:00        Tottenham      1.5   4–1      0.5
# 3   1  Sat 2022-08-06  15:00    Newcastle Utd      1.7   2–0      0.3
# 4   1  Sat 2022-08-06  15:00     Leeds United      0.8   2–1      1.3
#
#               away attendance  ...  match_report notes home_team_id  \
# 0          Arsenal     25,286  ...  Match Report           47c64c55
# 1        Liverpool     22,207  ...  Match Report           fd962109
# 2      Southampton     61,732  ...  Match Report           361ca564
# 3  Nott'ham Forest     52,245  ...  Match Report           b2b47a98
# 4           Wolves     36,347  ...  Match Report           5bfb9659
#
#   away_team_id                                       fixture_link  \
# 0     18bb7c10  https://fbref.com/en/matches/e62f6e78/Crystal-...
# 1     822bd0ba  https://fbref.com/en/matches/6713c1dc/Fulham-L...
# 2     33c895d4  https://fbref.com/en/matches/09d8a999/Tottenha...
# 3     e4a775cb  https://fbref.com/en/matches/1ac96eb4/Newcastl...
# 4     8cec06e1  https://fbref.com/en/matches/82702941/Leeds-Un...
#
#               kickoff home_score away_score  season_name  competition_id
# 0 2022-08-05 20:00:00        0.0        2.0    2022_2023               9
# 1 2022-08-06 12:30:00        2.0        2.0    2022_2023               9
# 2 2022-08-06 15:00:00        4.0        1.0    2022_2023               9
# 3 2022-08-06 15:00:00        2.0        0.0    2022_2023               9
# 4 2022-08-06 15:00:00        2.0        1.0    2022_2023               9
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Get stats for a given match
#
# Get match_url and grab id for one of the teams (will choose home team here)
#
# Example match: Crystal Palace vs Arsenal (home side: Palace)

# %%
match_url = fixtures_df.fixture_link.iloc[0]
home_team_id = fixtures_df.home_team_id.iloc[0]
away_team_id = fixtures_df.away_team_id.iloc[0]

# %% [markdown]
# Get dictionary for stats for given match

# %%
fixture_stat_dict = fb.get_fixture_stats(
    fixture_url = match_url, 
    home_id = home_team_id, 
    away_id = away_team_id,
)

# %% [markdown]
# Demo of fetching stats from below list:
# * summary
# * passing
# * passing_types
# * defense
# * possession
# * misc
# * keeper
# * shots
#
# Fetching match data for shots

# %%
fixture_stat_dict['summary'].head(5)
# Out:
#                     Player   #   Nation    Pos     Age Min Performance Gls  \
# 0          Odsonne Édouard  22   fr FRA     FW  24-201  57               0
# 1     Jean-Philippe Mateta  14   fr FRA     FW  25-038  33               0
# 2            Wilfried Zaha  11   ci CIV     LW  29-268  90               0
# 3              Jordan Ayew   9   gh GHA  RW,AM  30-328  90               0
# 4             Eberechi Eze  10  eng ENG     AM  24-037  85               0
#
#   Performance Ast Performance PK Performance PKatt  ... Passes Cmp Passes Att  \
# 0               0              0                 0  ...          3          6
# 1               0              0                 0  ...          8         10
# 2               0              0                 0  ...         30         39
# 3               0              0                 0  ...         27         34
# 4               0              0                 0  ...         32         41
#
#   Passes Cmp% Passes PrgP Carries Carries Carries PrgC Take-Ons Att  \
# 0        50.0           0              12            2            2
# 1        80.0           0               8            1            0
# 2        76.9           2              44            7            5
# 3        79.4           0              34            5            9
# 4        78.0           0              34            1            4
#
#   Take-Ons Succ player_id                                        player_link
# 0             1  0562b7f1  https://fbref.com/en/players/0562b7f1/Odsonne-...
# 1             0  50e6dc35  https://fbref.com/en/players/50e6dc35/Jean-Phi...
# 2             3  b2bc3b1f  https://fbref.com/en/players/b2bc3b1f/Wilfried...
# 3             6  da052c14  https://fbref.com/en/players/da052c14/Jordan-Ayew
# 4             1  ae4fc6a4  https://fbref.com/en/players/ae4fc6a4/Eberechi...
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Player stats from top five leagues
#
# Get standard data table

# %%
big5_players_standard_df = fb.get_big5_player_stats('standard', season_name)

# %%
big5_players_standard_df.head(5)
# Out:
#   rank        player_name country position            team     competition  \
# 0    1   Brenden Aaronson     USA    MF,FW    Leeds United  Premier League
# 1    2    Paxten Aaronson     USA       MF  Eint Frankfurt      Bundesliga
# 2    3   Yunis Abdelhamid     MAR       DF           Reims         Ligue 1
# 3    4      Himad Abdelli     FRA    MF,FW          Angers         Ligue 1
# 4    5  Salis Abdul Samed     GHA       MF            Lens         Ligue 1
#
#     age    born  matches_played  starts  ...  expected_assists_per_90  \
# 0  22.0  2000.0            26.0    23.0  ...                     0.17
# 1  19.0  2003.0             1.0     0.0  ...                     0.00
# 2  35.0  1987.0            28.0    28.0  ...                     0.02
# 3  23.0  1999.0            20.0    14.0  ...                     0.14
# 4  23.0  2000.0            26.0    26.0  ...                     0.06
#
#    xg_plus_expected_assists_per_90  non_penalty_xg_per_90  \
# 0                             0.31                   0.14
# 1                             0.00                   0.00
# 2                             0.08                   0.06
# 3                             0.20                   0.06
# 4                             0.09                   0.03
#
#    non_penalty_xg_plus_expected_assists_per_90  matches  goalkeeper  defender  \
# 0                                         0.31  Matches       False     False
# 1                                         0.00  Matches       False     False
# 2                                         0.08  Matches       False      True
# 3                                         0.20  Matches       False     False
# 4                                         0.09  Matches       False     False
#
#    midfielder  attacker  season_name
# 0        True      True    2022-2023
# 1        True     False    2022-2023
# 2       False     False    2022-2023
# 3        True      True    2022-2023
# 4        True     False    2022-2023
#
# [5 rows x 43 columns]

# %% [markdown]
# Get passing table

# %%
big5_players_defense_df = fb.get_big5_player_stats('defense', season_name)

# %%
big5_players_defense_df.head(5)
# Out:
#     Rk        player_name country position            team     competition  \
# 0  1.0   Brenden Aaronson     USA    MF,FW    Leeds United  Premier League
# 1  2.0    Paxten Aaronson     USA       MF  Eint Frankfurt      Bundesliga
# 2  3.0   Yunis Abdelhamid     MAR       DF           Reims         Ligue 1
# 3  4.0      Himad Abdelli     FRA    MF,FW          Angers         Ligue 1
# 4  5.0  Salis Abdul Samed     GHA       MF            Lens         Ligue 1
#
#   age    born  no_of_nineties  tackles  ...  \
# 0  22  2000.0            21.6     34.0  ...
# 1  19  2003.0             0.1      0.0  ...
# 2  35  1987.0            28.0     66.0  ...
# 3  23  1999.0            14.0     40.0  ...
# 4  23  2000.0            26.0     39.0  ...
#
#    attempted_tackles_on_dribblers_per_90  \
# 0                                   1.62
# 1                                   0.00
# 2                                   1.43
# 3                                   2.36
# 4                                   1.50
#
#    unsuccessful_tackles_on_dribblers_per_90  blocks_per_90  \
# 0                                      1.06           1.62
# 1                                      0.00           0.00
# 2                                      0.29           1.96
# 3                                      1.00           1.29
# 4                                      0.65           1.15
#
#    shots_blocked_per_90  passes_blocked_per_90  interceptions_per_90  \
# 0                  0.14                   1.48                  0.09
# 1                  0.00                   0.00                  0.00
# 2                  0.71                   1.25                  1.82
# 3                  0.07                   1.21                  1.07
# 4                  0.27                   0.88                  1.00
#
#    tackles_plus_interceptions_per_90  clearances_per_90  errors_per_90  \
# 0                               1.67               0.28           0.05
# 1                               0.00               0.00           0.00
# 2                               4.18               3.54           0.04
# 3                               3.93               0.64           0.00
# 4                               2.50               0.65           0.00
#
#    season_name
# 0    2022-2023
# 1    2022-2023
# 2    2022-2023
# 3    2022-2023
# 4    2022-2023
#
# [5 rows x 46 columns]

# %% [markdown]
# # Conclusion
#
# This notebook successfully fetches and cleans data from FBref for fixtures, match stats and player stats. This data can now be used various analysis and modelling for teams and players across Europe's top five teams.
#
# Possible next steps:
# * Team analysis for the current season
# * Categorise teams into play style
# * Use data from fbref to predict football outcomes
